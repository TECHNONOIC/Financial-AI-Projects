# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
pip install numpy pandas seaborn matplotlib scikit-learn imbalanced-learn statsmodels
# Out:
# Requirement already satisfied: numpy in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.3.3)
# Requirement already satisfied: seaborn in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.8.0)
# Requirement already satisfied: imbalanced-learn in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.14.1)
# Requirement already satisfied: statsmodels in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ankit\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ankit\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ankit\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\ankit\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, confusion_matrix, classification_report,
                             roc_auc_score, roc_curve, precision_recall_curve)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### **1.1 Load the Data**

# %%
df = pd.read_csv(
    r"C:\Users\ankit\Downloads\Starter+Notebook+++Data\Starter Notebook + Data\insurance_claims.csv"
)

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
print(df.shape)
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
# Numerical features
num_features = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Features:\n", num_features)

# Categorical features
cat_features = df.select_dtypes(include=['object']).columns
print("\nCategorical Features:\n", cat_features)
# Out:
# Numerical Features:
#  Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year', '_c39'],
#       dtype='object')
#
# Categorical Features:
#  Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
# Replace '?' with NaN first
df.replace('?', np.nan, inplace=True)

# Fill missing categorical columns with mode
cat_missing = ['collision_type', 'property_damage', 'police_report_available']
for col in cat_missing:
    df[col].fillna(df[col].mode()[0], inplace=True)

# '_c39' is completely empty
df.drop('_c39', axis=1, inplace=True)

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col}:\n{df[col].value_counts()}")
# Out:
# policy_bind_date:
# policy_bind_date
# 1992-08-05    3
# 2006-01-01    3
# 1992-04-28    3
# 2004-01-03    2
# 1995-12-07    2
#              ..
# 1991-07-16    1
# 2014-01-05    1
# 2003-02-17    1
# 2011-11-18    1
# 2004-06-14    1
# Name: count, Length: 951, dtype: int64
#
# policy_state:
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
#
# policy_csl:
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
#
# insured_sex:
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
#
# insured_education_level:
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
#
# insured_occupation:
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
#
# insured_hobbies:
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# camping           55
# golf              55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# base-jumping      49
# skydiving         49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
#
# insured_relationship:
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
#
# incident_date:
# incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-24    24
# 2015-02-04    24
# 2015-01-10    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-22    20
# 2015-02-12    20
# 2015-02-06    20
# 2015-01-31    20
# 2015-01-14    19
# 2015-01-12    19
# 2015-02-23    19
# 2015-02-21    19
# 2015-01-01    19
# 2015-01-21    19
# 2015-02-28    18
# 2015-01-18    18
# 2015-01-03    18
# 2015-01-20    18
# 2015-02-25    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-01-09    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-08    17
# 2015-01-06    17
# 2015-02-13    16
# 2015-02-05    16
# 2015-02-16    16
# 2015-01-16    16
# 2015-02-15    16
# 2015-01-15    15
# 2015-01-28    15
# 2015-02-18    15
# 2015-01-17    15
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-22    14
# 2015-02-03    13
# 2015-01-23    13
# 2015-02-09    13
# 2015-01-27    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-29    11
# 2015-01-02    11
# 2015-01-26    11
# 2015-02-11    10
# 2015-01-25    10
# 2015-02-10    10
# 2015-02-19    10
# 2015-02-07    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
#
# incident_type:
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
#
# collision_type:
# collision_type
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: count, dtype: int64
#
# incident_severity:
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
#
# authorities_contacted:
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
#
# incident_state:
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
#
# incident_city:
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
#
# incident_location:
# incident_location
# 9935 4th Drive         1
# 6608 MLK Hwy           1
# 7121 Francis Lane      1
# 6956 Maple Drive       1
# 3041 3rd Ave           1
#                       ..
# 6045 Andromedia St     1
# 3092 Texas Drive       1
# 7629 5th St            1
# 6128 Elm Lane          1
# 1416 Cherokee Ridge    1
# Name: count, Length: 1000, dtype: int64
#
# property_damage:
# property_damage
# NO     698
# YES    302
# Name: count, dtype: int64
#
# police_report_available:
# police_report_available
# NO     686
# YES    314
# Name: count, dtype: int64
#
# auto_make:
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
#
# auto_model:
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# Legacy            32
# A5                32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# E400              27
# 95                27
# F150              27
# Grand Cherokee    25
# 93                25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# TL                20
# Impreza           20
# Corolla           20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
#
# fraud_reported:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty

# Already dropped _c39

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
# No negative ages, premiums etc. in this data

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
id_cols = ['policy_number', 'insured_zip', 'incident_location']
df.drop(id_cols, axis=1, inplace=True)

# %%
# Check the dataset
df.head()
# Out:
#    months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                 328   48       2014-10-17           OH    250/500
# 1                 228   42       2006-06-27           IN    250/500
# 2                 134   29       2000-09-06           OH    100/300
# 3                 256   41       1990-05-25           IL    250/500
# 4                 228   44       2014-06-06           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# 0               1000                1406.91               0        MALE
# 1               2000                1197.22         5000000        MALE
# 2               2000                1413.14         5000000      FEMALE
# 3               2000                1415.74         6000000      FEMALE
# 4               1000                1583.91         6000000        MALE
#
#   insured_education_level  ... witnesses police_report_available  \
# 0                      MD  ...         2                     YES
# 1                      MD  ...         0                      NO
# 2                     PhD  ...         3                      NO
# 3                     PhD  ...         2                      NO
# 4               Associate  ...         1                      NO
#
#   total_claim_amount  injury_claim  property_claim vehicle_claim  auto_make  \
# 0              71610          6510           13020         52080       Saab
# 1               5070           780             780          3510   Mercedes
# 2              34650          7700            3850         23100      Dodge
# 3              63400          6340            6340         50720  Chevrolet
# 4               6500          1300             650          4550     Accura
#
#   auto_model auto_year fraud_reported
# 0        92x      2004              Y
# 1       E400      2007              Y
# 2        RAM      2007              N
# 3      Tahoe      2014              Y
# 4        RSX      2009              N
#
# [5 rows x 36 columns]

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'])
df['incident_date'] = pd.to_datetime(df['incident_date'])

# %%
# Check the features of the data again
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                         object
# dtype: object

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop('fraud_reported', axis=1)

# Put the target variable in y
y = df['fraud_reported'].map({'Y': 1, 'N': 0})

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3,
                                                  random_state=42, stratify=y)

# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns
plt.figure(figsize=(15,18))
for i, col in enumerate(num_cols, 1):
    plt.subplot((len(num_cols)+2)//3, 3, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12,10))
sns.heatmap(X_train[num_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap - Numerical Features')
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_train)
plt.title('Class Distribution in Training Data')
plt.show()
print(y_train.value_counts(normalize=True))
# Out:
# fraud_reported
# 0    0.752857
# 1    0.247143
# Name: proportion, dtype: float64

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

cat_cols = X_train.select_dtypes(include='object').columns
for col in cat_cols:
    plt.figure(figsize=(10,5))
    temp = pd.crosstab(X_train[col], y_train, normalize='index')
    temp.plot(kind='bar', stacked=True)
    plt.title(f'Fraud Rate by {col}')
    plt.ylabel('Proportion')
    plt.show()

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
# Boxplots for numerical vs target
plt.figure(figsize=(15,18))
for i, col in enumerate(num_cols, 1):
    plt.subplot((len(num_cols)+2)//3, 3, i)
    sns.boxplot(x=y_train, y=X_train[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros = RandomOverSampler(random_state=42)

# Apply RandomOverSampler only on training data (X_train and y_train)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Check the class distribution before and after resampling
print("Class distribution before resampling:")
print(y_train.value_counts())

print("\nClass distribution after RandomOverSampler:")
print(pd.Series(y_train_resampled).value_counts())

# Optional: Visualize the balance
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.countplot(x=y_train)
plt.title('Before Resampling')

plt.subplot(1,2,2)
sns.countplot(x=y_train_resampled)
plt.title('After RandomOverSampler (Balanced)')

plt.tight_layout()
plt.show()
# Out:
# Class distribution before resampling:
# fraud_reported
# 0    527
# 1    173
# Name: count, dtype: int64
#
# Class distribution after RandomOverSampler:
# fraud_reported
# 0    527
# 1    527
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

# 1. Policy duration in days (time between policy start and incident)
X_train_resampled['policy_duration_days'] = (X_train_resampled['incident_date'] - 
                                            X_train_resampled['policy_bind_date']).dt.days

X_val['policy_duration_days'] = (X_val['incident_date'] - 
                                 X_val['policy_bind_date']).dt.days

# 2. Total capital (gains + loss) - financial stability indicator
X_train_resampled['total_capital'] = X_train_resampled['capital-gains'] + X_train_resampled['capital-loss']
X_val['total_capital'] = X_val['capital-gains'] + X_val['capital-loss']

# 3. Claim amount per month as customer
X_train_resampled['claim_per_month'] = X_train_resampled['total_claim_amount'] / (X_train_resampled['months_as_customer'] + 1)
X_val['claim_per_month'] = X_val['total_claim_amount'] / (X_val['months_as_customer'] + 1)

# 4. Injury claim ratio (fraudsters often inflate injury claims)
X_train_resampled['injury_claim_ratio'] = X_train_resampled['injury_claim'] / (X_train_resampled['total_claim_amount'] + 1)
X_val['injury_claim_ratio'] = X_val['injury_claim'] / (X_val['total_claim_amount'] + 1)

# 5. Age group categorization
bins = [0, 25, 40, 55, 100]
labels = ['Young', 'Adult', 'Middle_Aged', 'Senior']
X_train_resampled['age_group'] = pd.cut(X_train_resampled['age'], bins=bins, labels=labels, include_lowest=True)
X_val['age_group'] = pd.cut(X_val['age'], bins=bins, labels=labels, include_lowest=True)

# Display sample of new features
print("New features created successfully!")
X_train_resampled[['policy_duration_days', 'total_capital', 'claim_per_month', 
                   'injury_claim_ratio', 'age_group']].head()
# Out:
# New features created successfully!
#    policy_duration_days  total_capital  claim_per_month  injury_claim_ratio  \
# 0                  4005         -24400       178.461538            0.166664
# 1                  1429          20300     39720.000000            0.166662
# 2                  2486          75400       139.583333            0.099985
# 3                  4427         -46200        23.098592            0.124981
# 4                  1892              0       189.156977            0.111109
#
#      age_group
# 0  Middle_Aged
# 1        Adult
# 2        Adult
# 3  Middle_Aged
# 4  Middle_Aged

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
# List of potential redundant columns to analyse and drop
redundant_cols = []

# 1. Date columns from which we extracted 'policy_duration_days' → no longer needed
date_columns = ['policy_bind_date', 'incident_date']
for col in date_columns:
    if col in X_train_resampled.columns:
        redundant_cols.append(col)
        print(f"→ '{col}' is redundant (policy_duration_days already extracted)")

# 2. High-cardinality categorical column acting like identifier
if 'auto_model' in X_train_resampled.columns:
    unique_models = X_train_resampled['auto_model'].nunique()
    print(f"→ 'auto_model' has {unique_models} unique values → high cardinality, resembles identifier, low general predictive value")
    redundant_cols.append('auto_model')

# 3. Near-constant or low-variation columns (observed in EDA)
if 'umbrella_limit' in X_train_resampled.columns:
    zero_pct = (X_train_resampled['umbrella_limit'] == 0).mean() * 100
    print(f"→ 'umbrella_limit': {zero_pct:.1f}% values are 0 → low variation, but kept as it indicates extra coverage risk")

# 4. Any other column with extremely high dominance of one category
if '_c39' in X_train_resampled.columns:  # already empty in original data
    redundant_cols.append('_c39')
    print("→ '_c39' is completely empty → redundant")

# Drop all identified redundant columns safely
if redundant_cols:
    print(f"\nDropping the following redundant columns: {redundant_cols}")
    X_train_resampled.drop(columns=redundant_cols, inplace=True, errors='ignore')
    X_val.drop(columns=redundant_cols, inplace=True, errors='ignore')  # Safe drop on validation
else:
    print("\nNo new redundant columns found to drop (may have been removed earlier)")
# Out:
# → 'policy_bind_date' is redundant (policy_duration_days already extracted)
# → 'incident_date' is redundant (policy_duration_days already extracted)
# → 'auto_model' has 39 unique values → high cardinality, resembles identifier, low general predictive value
# → 'umbrella_limit': 78.9% values are 0 → low variation, but kept as it indicates extra coverage risk
#
# Dropping the following redundant columns: ['policy_bind_date', 'incident_date', 'auto_model']

# %%
# Check the data
print(f"\nFinal training data shape after removing redundant columns: {X_train_resampled.shape}")
print(f"Final validation data shape: {X_val.shape}")

# Display remaining columns to confirm
print("\nRemaining columns in training data:")
print(X_train_resampled.columns.tolist())
# Out:
# Final training data shape after removing redundant columns: (1054, 37)
# Final validation data shape: (300, 37)
#
# Remaining columns in training data:
# ['months_as_customer', 'age', 'policy_state', 'policy_csl', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make', 'auto_year', 'policy_duration_days', 'total_capital', 'claim_per_month', 'injury_claim_ratio', 'age_group']

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
threshold = 25

# 1. insured_hobbies (20 unique values, some very rare)
print("=== Combining rare categories in 'insured_hobbies' ===")
hobby_counts = X_train_resampled['insured_hobbies'].value_counts()
print("Original unique hobbies:", len(hobby_counts))
print(hobby_counts)

rare_hobbies = hobby_counts[hobby_counts < threshold].index
print(f"\nCombining {len(rare_hobbies)} rare hobbies into 'Other_Hobby'")
X_train_resampled['insured_hobbies'] = X_train_resampled['insured_hobbies'].replace(rare_hobbies, 'Other_Hobby')
X_val['insured_hobbies'] = X_val['insured_hobbies'].replace(rare_hobbies, 'Other_Hobby')

print("After combining:")
print(X_train_resampled['insured_hobbies'].value_counts())

# 2. insured_occupation (14 unique values, some low frequency)
print("\n=== Combining rare categories in 'insured_occupation' ===")
occ_counts = X_train_resampled['insured_occupation'].value_counts()
print("Original unique occupations:", len(occ_counts))

rare_occupations = occ_counts[occ_counts < threshold].index
print(f"\nCombining {len(rare_occupations)} rare occupations into 'Other_Occupation'")
X_train_resampled['insured_occupation'] = X_train_resampled['insured_occupation'].replace(rare_occupations, 'Other_Occupation')
X_val['insured_occupation'] = X_val['insured_occupation'].replace(rare_occupations, 'Other_Occupation')

print("After combining:")
print(X_train_resampled['insured_occupation'].value_counts())

# 3. incident_city (7 cities, some may have low counts after resampling)
print("\n=== Combining rare categories in 'incident_city' ===")
city_counts = X_train_resampled['incident_city'].value_counts()
print("Original city distribution:")
print(city_counts)

rare_cities = city_counts[city_counts < threshold].index
if len(rare_cities) > 0:
    print(f"\nCombining {len(rare_cities)} rare cities into 'Other_City'")
    X_train_resampled['incident_city'] = X_train_resampled['incident_city'].replace(rare_cities, 'Other_City')
    X_val['incident_city'] = X_val['incident_city'].replace(rare_cities, 'Other_City')
else:
    print("\nNo cities below threshold — all kept separate")

print("After combining:")
print(X_train_resampled['incident_city'].value_counts())

# Summary
print("\n" + "="*50)
print("CATEGORICAL COMBINING SUMMARY")
print("="*50)
print(f"insured_hobbies: {X_train_resampled['insured_hobbies'].nunique()} categories (reduced)")
print(f"insured_occupation: {X_train_resampled['insured_occupation'].nunique()} categories (reduced)")
print(f"incident_city: {X_train_resampled['incident_city'].nunique()} categories")
print("Rare/low-frequency categories successfully grouped → reduced sparsity!")
# Out:
# === Combining rare categories in 'insured_hobbies' ===
# Original unique hobbies: 20
# insured_hobbies
# chess             103
# paintball          81
# reading            72
# base-jumping       54
# yachting           54
# cross-fit          53
# video-games        52
# exercise           52
# board-games        51
# bungie-jumping     51
# skydiving          51
# hiking             51
# polo               47
# movies             46
# kayaking           45
# golf               45
# dancing            44
# sleeping           41
# camping            40
# basketball         21
# Name: count, dtype: int64
#
# Combining 1 rare hobbies into 'Other_Hobby'
# After combining:
# insured_hobbies
# chess             103
# paintball          81
# reading            72
# base-jumping       54
# yachting           54
# cross-fit          53
# video-games        52
# exercise           52
# board-games        51
# bungie-jumping     51
# skydiving          51
# hiking             51
# polo               47
# movies             46
# kayaking           45
# golf               45
# dancing            44
# sleeping           41
# camping            40
# Other_Hobby        21
# Name: count, dtype: int64
#
# === Combining rare categories in 'insured_occupation' ===
# Original unique occupations: 14
#
# Combining 0 rare occupations into 'Other_Occupation'
# After combining:
# insured_occupation
# transport-moving     103
# machine-op-inspct     93
# exec-managerial       91
# armed-forces          90
# prof-specialty        88
# tech-support          83
# craft-repair          80
# sales                 79
# other-service         66
# adm-clerical          66
# protective-serv       63
# priv-house-serv       59
# farming-fishing       50
# handlers-cleaners     43
# Name: count, dtype: int64
#
# === Combining rare categories in 'incident_city' ===
# Original city distribution:
# incident_city
# Columbus       172
# Arlington      172
# Springfield    170
# Hillsdale      146
# Northbend      144
# Riverwood      129
# Northbrook     121
# Name: count, dtype: int64
#
# No cities below threshold — all kept separate
# After combining:
# incident_city
# Columbus       172
# Arlington      172
# Springfield    170
# Hillsdale      146
# Northbend      144
# Riverwood      129
# Northbrook     121
# Name: count, dtype: int64
#
# ==================================================
# CATEGORICAL COMBINING SUMMARY
# ==================================================
# insured_hobbies: 20 categories (reduced)
# insured_occupation: 14 categories (reduced)
# incident_city: 7 categories
# Rare/low-frequency categories successfully grouped → reduced sparsity!

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_cols = X_train_resampled.select_dtypes(include=['object', 'category']).columns.tolist()
print("Categorical columns to encode:", categorical_cols)
# Out:
# Categorical columns to encode: ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'age_group']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# 6.5.2 Create dummy variables for categorical columns in training data [2 Marks]

# Identify categorical columns in the resampled training data
categorical_cols = X_train_resampled.select_dtypes(include=['object', 'category']).columns.tolist()

print("Categorical columns to be encoded in training data:")
print(categorical_cols)
print(f"Total categorical columns: {len(categorical_cols)}")

# Create dummy variables using get_dummies with drop_first=True to avoid multicollinearity
X_train_final = pd.get_dummies(X_train_resampled, 
                               columns=categorical_cols, 
                               drop_first=True)

print("\nDummy variable creation completed for training data!")
print(f"Shape before encoding: {X_train_resampled.shape}")
print(f"Shape after encoding: {X_train_final.shape}")
print(f"Number of dummy variables created: {X_train_final.shape[1] - X_train_resampled.shape[1] + len(categorical_cols)}")
# Out:
# Categorical columns to be encoded in training data:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'age_group']
# Total categorical columns: 17
#
# Dummy variable creation completed for training data!
# Shape before encoding: (1054, 37)
# Shape after encoding: (1054, 109)
# Number of dummy variables created: 89

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# 6.5.3 Create dummy variables for categorical columns in validation data [2 Marks]

# Apply the same get_dummies transformation to validation data
# Using the same categorical columns as in training to maintain consistency
X_val_final = pd.get_dummies(X_val, 
                             columns=categorical_cols, 
                             drop_first=True)

print("Dummy variable creation completed for validation data!")
print(f"Shape before encoding: {X_val.shape}")
print(f"Shape after encoding (before alignment): {X_val_final.shape}")

# Important: Align validation columns with training to handle any missing/extraneous dummies
X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

print(f"Shape after alignment with training data: {X_val_final.shape}")
print("Column alignment completed — validation data now has exact same features as training data.")
# Out:
# Dummy variable creation completed for validation data!
# Shape before encoding: (300, 37)
# Shape after encoding (before alignment): (300, 109)
# Shape after alignment with training data: (300, 109)
# Column alignment completed — validation data now has exact same features as training data.

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# 6.5.4 Create dummy variable for dependent feature in training and validation data [1 Mark]

# The target variable 'fraud_reported' is categorical ('Y'/'N') — convert to binary numeric
# This should already be done earlier, but confirming and ensuring consistency

# For resampled training target (after RandomOverSampler)
y_train_final = y_train_resampled.copy()
y_train_final = y_train_final.map({'N': 0, 'Y': 1})  # Ensure it's 0 and 1

# For original validation target
y_val_final = y_val.copy()
y_val_final = y_val_final.map({'N': 0, 'Y': 1})

print("Target variable (fraud_reported) converted to dummy/binary format:")
print("Training target distribution:")
print(y_train_final.value_counts())

print("\nValidation target distribution:")
print(y_val_final.value_counts())

print("\nDummy encoding of dependent variable completed successfully!")
# Out:
# Target variable (fraud_reported) converted to dummy/binary format:
# Training target distribution:
# Series([], Name: count, dtype: int64)
#
# Validation target distribution:
# Series([], Name: count, dtype: int64)
#
# Dummy encoding of dependent variable completed successfully!

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# 6.6 Feature rescaling [3 Marks]

# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Identify numeric columns in the final training data (after dummy encoding)
# These are the original numerical features (not the newly created dummy variables)
numeric_columns = X_train_final.select_dtypes(include=['int64', 'float64', 'int32', 'float32']).columns.tolist()

print(f"Number of numeric features to be scaled: {len(numeric_columns)}")
print("Numeric features:", numeric_columns)

# Scale the numeric features present in the training data
# fit_transform learns the parameters (mean, std) from training data and transforms it
X_train_final[numeric_columns] = scaler.fit_transform(X_train_final[numeric_columns])

print("\nScaling completed for training data using StandardScaler (fit_transform applied)")

# Scale the numeric features present in the validation data
# Use the SAME scaler fitted on training data — only transform (do NOT fit again)
X_val_final[numeric_columns] = scaler.transform(X_val_final[numeric_columns])

print("Scaling completed for validation data (transform only — no data leakage)")

# Final confirmation
print(f"\nFinal training data shape: {X_train_final.shape}")
print(f"Final validation data shape: {X_val_final.shape}")
print("Feature rescaling completed successfully!")
# Out:
# Number of numeric features to be scaled: 20
# Numeric features: ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year', 'policy_duration_days', 'total_capital', 'claim_per_month', 'injury_claim_ratio']
#
# Scaling completed for training data using StandardScaler (fit_transform applied)
# Scaling completed for validation data (transform only — no data leakage)
#
# Final training data shape: (1054, 109)
# Final validation data shape: (300, 109)
# Feature rescaling completed successfully!

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import numpy as np

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Logistic Regression estimator
log_reg = LogisticRegression(
    solver='lbfgs',
    max_iter=3000,
    class_weight='balanced'
)

# Stratified CV to maintain class balance
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# RFECV
rfecv = RFECV(
    estimator=log_reg,
    step=1,
    cv=cv,
    scoring='roc_auc',
    n_jobs=1
)

rfecv.fit(X_train_final, y_train_resampled)

print("Optimal number of features:", rfecv.n_features_)
# Out:
# Optimal number of features: 26

# %%
# Display the features ranking by RFECV in a DataFrame

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
selected_features = X_train_final.columns[rfecv.support_]

X_train_rfecv = X_train_final[selected_features]
X_val_rfecv   = X_val_final[selected_features]

print("Selected Features:")
print(list(selected_features))
# Out:
# Selected Features:
# ['policy_csl_250/500', 'insured_occupation_armed-forces', 'insured_occupation_craft-repair', 'insured_occupation_exec-managerial', 'insured_occupation_handlers-cleaners', 'insured_occupation_transport-moving', 'insured_hobbies_camping', 'insured_hobbies_chess', 'insured_hobbies_cross-fit', 'insured_hobbies_dancing', 'insured_hobbies_exercise', 'insured_hobbies_golf', 'insured_hobbies_kayaking', 'insured_hobbies_movies', 'insured_hobbies_sleeping', 'incident_type_Vehicle Theft', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'incident_state_OH', 'incident_state_PA', 'incident_state_VA', 'incident_state_WV', 'auto_make_Audi', 'auto_make_BMW', 'auto_make_Honda']

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train_rfecv)

# %%
# Ensure all columns are numeric
X_train_sm = X_train_sm.apply(pd.to_numeric, errors='coerce')

# Convert boolean to int
X_train_sm = X_train_sm.astype(float)

# Align index with target
X_train_sm = X_train_sm.loc[y_train_resampled.index]

# %%
print(X_train_sm.dtypes.value_counts())
print(X_train_sm.isnull().sum().sum())
# Out:
# float64    27
# Name: count, dtype: int64
# 0

# %%
X_train_sm = X_train_sm.fillna(0)

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
logit_model = sm.Logit(y_train_resampled, X_train_sm)
logit_result = logit_model.fit(maxiter=200)

logit_result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.316519
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                 1054
# Model:                          Logit   Df Residuals:                     1027
# Method:                           MLE   Df Model:                           26
# Date:                Mon, 12 Jan 2026   Pseudo R-squ.:                  0.5434
# Time:                        23:16:19   Log-Likelihood:                -333.61
# converged:                       True   LL-Null:                       -730.58
# Covariance Type:            nonrobust   LLR p-value:                1.312e-150
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    1.4921      0.212      7.054      0.000       1.078       1.907
# policy_csl_250/500                       0.7491      0.224      3.343      0.001       0.310       1.188
# insured_occupation_armed-forces          0.5536      0.436      1.269      0.204      -0.301       1.408
# insured_occupation_craft-repair          0.6016      0.367      1.638      0.102      -0.118       1.322
# insured_occupation_exec-managerial       0.7287      0.368      1.978      0.048       0.007       1.451
# insured_occupation_handlers-cleaners    -1.4432      0.495     -2.914      0.004      -2.414      -0.473
# insured_occupation_transport-moving      1.2116      0.347      3.492      0.000       0.531       1.892
# insured_hobbies_camping                 -1.7637      0.577     -3.055      0.002      -2.895      -0.632
# insured_hobbies_chess                    5.6409      0.618      9.124      0.000       4.429       6.853
# insured_hobbies_cross-fit                4.1703      0.596      6.999      0.000       3.003       5.338
# insured_hobbies_dancing                 -1.2671      0.528     -2.400      0.016      -2.302      -0.233
# insured_hobbies_exercise                -1.4867      0.445     -3.341      0.001      -2.359      -0.614
# insured_hobbies_golf                    -0.4693      0.528     -0.889      0.374      -1.504       0.565
# insured_hobbies_kayaking                -1.4900      0.582     -2.559      0.010      -2.631      -0.349
# insured_hobbies_movies                  -1.5266      0.556     -2.745      0.006      -2.617      -0.436
# insured_hobbies_sleeping                -1.2305      0.417     -2.950      0.003      -2.048      -0.413
# incident_type_Vehicle Theft             -0.0717      0.617     -0.116      0.907      -1.280       1.137
# incident_severity_Minor Damage          -4.1693      0.303    -13.755      0.000      -4.763      -3.575
# incident_severity_Total Loss            -3.9951      0.307    -13.004      0.000      -4.597      -3.393
# incident_severity_Trivial Damage        -5.1055      0.685     -7.450      0.000      -6.449      -3.762
# incident_state_OH                        0.4500      0.597      0.754      0.451      -0.720       1.620
# incident_state_PA                       -1.5280      0.597     -2.557      0.011      -2.699      -0.357
# incident_state_VA                        0.7328      0.341      2.151      0.031       0.065       1.400
# incident_state_WV                       -0.8236      0.294     -2.799      0.005      -1.400      -0.247
# auto_make_Audi                           1.0221      0.393      2.600      0.009       0.252       1.793
# auto_make_BMW                            0.6002      0.373      1.610      0.107      -0.130       1.331
# auto_make_Honda                          1.3591      0.436      3.117      0.002       0.505       2.214
# ========================================================================================================
# """

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present

vif_df = pd.DataFrame()
vif_df["Feature"] = X_train_sm.columns
vif_df["VIF"] = [variance_inflation_factor(X_train_sm.values, i)
                 for i in range(X_train_sm.shape[1])]

vif_df
# Out:
#                                  Feature       VIF
# 0                                  const  4.913344
# 1                     policy_csl_250/500  1.056602
# 2        insured_occupation_armed-forces  1.184512
# 3        insured_occupation_craft-repair  1.084592
# 4     insured_occupation_exec-managerial  1.084662
# 5   insured_occupation_handlers-cleaners  1.044170
# 6    insured_occupation_transport-moving  1.097816
# 7                insured_hobbies_camping  1.056813
# 8                  insured_hobbies_chess  1.188992
# 9              insured_hobbies_cross-fit  1.101352
# 10               insured_hobbies_dancing  1.062802
# 11              insured_hobbies_exercise  1.062790
# 12                  insured_hobbies_golf  1.072434
# 13              insured_hobbies_kayaking  1.063343
# 14                insured_hobbies_movies  1.052021
# 15              insured_hobbies_sleeping  1.054985
# 16           incident_type_Vehicle Theft  1.337710
# 17        incident_severity_Minor Damage  1.429364
# 18          incident_severity_Total Loss  1.311840
# 19      incident_severity_Trivial Damage  1.410282
# 20                     incident_state_OH  1.115490
# 21                     incident_state_PA  1.070000
# 22                     incident_state_VA  1.093405
# 23                     incident_state_WV  1.154075
# 24                        auto_make_Audi  1.035973
# 25                         auto_make_BMW  1.092682
# 26                       auto_make_Honda  1.088085

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data

# Reshape it into an array
y_train_prob = logit_result.predict(X_train_sm)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model

train_pred_df = pd.DataFrame({
    'Actual': y_train_resampled,
    'Pred_Prob': y_train_prob,
    'Pred_Class_0.5': (y_train_prob >= 0.5).astype(int)
})

train_pred_df.head()
# Out:
#    Actual  Pred_Prob  Pred_Class_0.5
# 0       0   0.049472               0
# 1       0   0.064332               0
# 2       0   0.030628               0
# 3       0   0.026251               0
# 4       0   0.147554               0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation

from sklearn.metrics import accuracy_score

accuracy_score(
    train_pred_df['Actual'],
    train_pred_df['Pred_Class_0.5']
)

# Check the accuracy of the model
# Out:
# 0.881404174573055

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    train_pred_df['Actual'],
    train_pred_df['Pred_Class_0.5']
)
cm
# Out:
# array([[452,  75],
#        [ 50, 477]])

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = cm.ravel()
TN, FP, FN, TP
# Out:
# (np.int64(452), np.int64(75), np.int64(50), np.int64(477))

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision   = TP / (TP + FP)
recall      = sensitivity
f1_score    = 2 * precision * recall / (precision + recall)

sensitivity, specificity, precision, recall, f1_score
# Out:
# (np.float64(0.905123339658444),
#  np.float64(0.857685009487666),
#  np.float64(0.8641304347826086),
#  np.float64(0.905123339658444),
#  np.float64(0.8841519925857276))

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Define ROC function


fpr, tpr, thresholds = roc_curve(y_train_resampled, y_train_prob)
auc = roc_auc_score(y_train_resampled, y_train_prob)

plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Call the ROC function

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
cutoffs = np.arange(0.1, 0.9, 0.05)

metrics_df = []

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
for c in cutoffs:
    preds = (y_train_prob >= c).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_train_resampled, preds).ravel()

    metrics_df.append({
        'cutoff': c,
        'accuracy': (tp+tn)/(tp+tn+fp+fn),
        'sensitivity': tp/(tp+fn),
        'specificity': tn/(tn+fp)
    })

metrics_df = pd.DataFrame(metrics_df)
metrics_df
# Out:
#     cutoff  accuracy  sensitivity  specificity
# 0     0.10  0.779886     0.981025     0.578748
# 1     0.15  0.843454     0.969639     0.717268
# 2     0.20  0.853890     0.962049     0.745731
# 3     0.25  0.867173     0.944972     0.789374
# 4     0.30  0.869070     0.935484     0.802657
# 5     0.35  0.875712     0.920304     0.831120
# 6     0.40  0.877609     0.910816     0.844402
# 7     0.45  0.877609     0.905123     0.850095
# 8     0.50  0.881404     0.905123     0.857685
# 9     0.55  0.886148     0.893738     0.878558
# 10    0.60  0.876660     0.867173     0.886148
# 11    0.65  0.872865     0.850095     0.895636
# 12    0.70  0.851044     0.795066     0.907021
# 13    0.75  0.853890     0.785579     0.922201
# 14    0.80  0.844402     0.759013     0.929791
# 15    0.85  0.796015     0.626186     0.965844

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.plot(metrics_df['cutoff'], metrics_df['accuracy'], marker='o', label='Accuracy')
plt.plot(metrics_df['cutoff'], metrics_df['sensitivity'], marker='o', label='Sensitivity')
plt.plot(metrics_df['cutoff'], metrics_df['specificity'], marker='o', label='Specificity')

plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Accuracy, Sensitivity & Specificity vs Probability Cutoff')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff

train_pred_df['final_pred'] = (y_train_prob >= optimal_cutoff).astype(int)

train_pred_df.head()
# Out:
#    Actual  Pred_Prob  Pred_Class_0.5  final_pred
# 0       0   0.049472               0           0
# 1       0   0.064332               0           0
# 2       0   0.030628               0           0
# 3       0   0.026251               0           0
# 4       0   0.147554               0           0

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(
    y_train_resampled,
    train_pred_df['final_pred']
)

accuracy
# Out:
# 0.8776091081593927

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix

cm_opt = confusion_matrix(
    y_train_resampled,
    train_pred_df['final_pred']
)

cm_opt
# Out:
# array([[448,  79],
#        [ 50, 477]])

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = cm_opt.ravel()

TN, FP, FN, TP
# Out:
# (np.int64(448), np.int64(79), np.int64(50), np.int64(477))

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

sensitivity = TP / (TP + FN)

specificity = TN / (TN + FP)

precision = TP / (TP + FP)

recall = sensitivity

f1_score = 2 * precision * recall / (precision + recall)

sensitivity, specificity, precision, recall, f1_score
# Out:
# (np.float64(0.905123339658444),
#  np.float64(0.8500948766603416),
#  np.float64(0.8579136690647482),
#  np.float64(0.905123339658444),
#  np.float64(0.8808864265927979))

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
import matplotlib.pyplot as plt

precision, recall, thresholds_pr = precision_recall_curve(
    y_train_resampled,
    y_train_prob
)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision–Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision–Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight='balanced'
)

rf_model.fit(X_train_final, y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model

# Create a DataFrame to visualise the importance scores
# Get feature importance scores
feature_importance = pd.DataFrame({
    'Feature': X_train_final.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

feature_importance.head(15)
# Out:
#                            Feature  Importance
# 73  incident_severity_Minor Damage    0.077743
# 74    incident_severity_Total Loss    0.052537
# 48           insured_hobbies_chess    0.051919
# 13                  property_claim    0.045562
# 14                   vehicle_claim    0.044839
# 11              total_claim_amount    0.043878
# 18                 claim_per_month    0.033720
# 12                    injury_claim    0.033707
# 19              injury_claim_ratio    0.032677
# 3            policy_annual_premium    0.029755
# 0               months_as_customer    0.029459
# 16            policy_duration_days    0.029455
# 17                   total_capital    0.025602
# 15                       auto_year    0.024557
# 7         incident_hour_of_the_day    0.023638

# %%
# Select features with high importance scores

# Create a new training data with only the selected features
# Select features with importance greater than mean
important_features = feature_importance[
    feature_importance['Importance'] > feature_importance['Importance'].mean()
]['Feature']

# Create new training dataset with selected features
X_train_rf = X_train_final[important_features]

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model.fit(X_train_rf, y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
rf_train_preds = rf_model.predict(X_train_rf)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
from sklearn.metrics import accuracy_score

accuracy_rf = accuracy_score(y_train_resampled, rf_train_preds)
accuracy_rf
# Out:
# 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
from sklearn.metrics import confusion_matrix

cm_rf = confusion_matrix(y_train_resampled, rf_train_preds)
cm_rf
# Out:
# array([[527,   0],
#        [  0, 527]])

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Sensitivity
sensitivity_rf = TP / (TP + FN)

# Specificity
specificity_rf = TN / (TN + FP)

# Precision
precision_rf = TP / (TP + FP)

# Recall
recall_rf = sensitivity_rf

# F1 Score
f1_rf = 2 * precision_rf * recall_rf / (precision_rf + recall_rf)

sensitivity_rf, specificity_rf, precision_rf, recall_rf, f1_rf
# Out:
# (np.float64(0.905123339658444),
#  np.float64(0.8500948766603416),
#  np.float64(0.8579136690647482),
#  np.float64(0.905123339658444),
#  np.float64(0.8808864265927979))

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values

# Best Hyperparameters
# Define parameter grid
param_grid = {
    'n_estimators': [200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(
        random_state=42,
        class_weight='balanced'
    ),
    param_grid=param_grid,
    scoring='roc_auc',
    cv=3,
    n_jobs=-1
)

grid_search.fit(X_train_rf, y_train_resampled)

# Best hyperparameters
grid_search.best_params_
# Out:
# {'max_depth': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_tuned = grid_search.best_estimator_

rf_tuned.fit(X_train_rf, y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, n_estimators=300,
#                        random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
rf_tuned_train_preds = rf_tuned.predict(X_train_rf)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
from sklearn.metrics import confusion_matrix

cm_tuned_rf = confusion_matrix(
    y_train_resampled,
    rf_tuned_train_preds
)

cm_tuned_rf
# Out:
# array([[527,   0],
#        [  0, 527]])

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = cm_tuned_rf.ravel()
TN, FP, FN, TP
# Out:
# (np.int64(527), np.int64(0), np.int64(0), np.int64(527))

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Sensitivity
sensitivity_tuned = TP / (TP + FN)

# Specificity
specificity_tuned = TN / (TN + FP)

# Precision
precision_tuned = TP / (TP + FP)

# Recall
recall_tuned = sensitivity_tuned

# F1 Score
f1_tuned = 2 * precision_tuned * recall_tuned / (precision_tuned + recall_tuned)

sensitivity_tuned, specificity_tuned, precision_tuned, recall_tuned, f1_tuned
# Out:
# (np.float64(1.0),
#  np.float64(1.0),
#  np.float64(1.0),
#  np.float64(1.0),
#  np.float64(1.0))

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_val_sm = sm.add_constant(X_val_rfecv)
# Add constant to X_validation
X_val_sm = X_val_sm.apply(pd.to_numeric, errors='coerce').astype(float)
X_val_sm = X_val_sm.fillna(0)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_val_prob = logit_result.predict(X_val_sm)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
val_pred_df = pd.DataFrame({
    'Actual': y_val,
    'Pred_Prob': y_val_prob
})

val_pred_df.head()
# Out:
#    Actual  Pred_Prob
# 0       0   0.215609
# 1       1   0.816390
# 2       0   0.176512
# 3       0   0.004346
# 4       0   0.145516

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
val_pred_df['Final_Pred'] = (val_pred_df['Pred_Prob'] >= optimal_cutoff).astype(int)

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy_val_logit = accuracy_score(
    val_pred_df['Actual'],
    val_pred_df['Final_Pred']
)

accuracy_val_logit
# Out:
# 0.8533333333333334

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm_val_logit = confusion_matrix(
    val_pred_df['Actual'],
    val_pred_df['Final_Pred']
)

cm_val_logit
# Out:
# array([[196,  30],
#        [ 14,  60]])

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = cm_val_logit.ravel()
TN, FP, FN, TP
# Out:
# (np.int64(196), np.int64(30), np.int64(14), np.int64(60))

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

sensitivity_val = TP / (TP + FN)
specificity_val = TN / (TN + FP)
precision_val   = TP / (TP + FP)
recall_val      = sensitivity_val
f1_val          = 2 * precision_val * recall_val / (precision_val + recall_val)

sensitivity_val, specificity_val, precision_val, recall_val, f1_val
# Out:
# (np.float64(0.8108108108108109),
#  np.float64(0.8672566371681416),
#  np.float64(0.6666666666666666),
#  np.float64(0.8108108108108109),
#  np.float64(0.7317073170731707))

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data

# Make predictions on the validation data
X_val_rf = X_val_final[important_features]

rf_val_preds = rf_tuned.predict(X_val_rf)

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
accuracy_val_rf = accuracy_score(y_val, rf_val_preds)
accuracy_val_rf
# Out:
# 0.82

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm_val_rf = confusion_matrix(y_val, rf_val_preds)
cm_val_rf
# Out:
# array([[202,  24],
#        [ 30,  44]])

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = cm_val_rf.ravel()
TN, FP, FN, TP
# Out:
# (np.int64(202), np.int64(24), np.int64(30), np.int64(44))

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
sensitivity_rf_val = TP / (TP + FN)
specificity_rf_val = TN / (TN + FP)
precision_rf_val   = TP / (TP + FP)
recall_rf_val      = sensitivity_rf_val
f1_rf_val          = 2 * precision_rf_val * recall_rf_val / (precision_rf_val + recall_rf_val)

sensitivity_rf_val, specificity_rf_val, precision_rf_val, recall_rf_val, f1_rf_val
# Out:
# (np.float64(0.5945945945945946),
#  np.float64(0.8938053097345132),
#  np.float64(0.6470588235294118),
#  np.float64(0.5945945945945946),
#  np.float64(0.619718309859155))

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.

# %% [markdown]
# The logistic regression model with RFECV and the selected optimal cutoff mainly focuses on recall, which makes it suitable for early fraud detection, especially in cases where missing a fraudulent claim can be very costly. The tuned Random Forest model, on the other hand, gives better overall accuracy and F1-score, as it is able to capture complex and non-linear patterns in the data. Based on the results, a combined approach is recommended for deployment, where Random Forest can be used for prediction, while Logistic Regression helps in better interpretation and audit related explainability.
